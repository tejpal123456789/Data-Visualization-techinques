# %% [markdown]
# <a href="https://colab.research.google.com/github/tejpal123456789/Data-Visualization-techinques/blob/main/titanic_data_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

data=pd.read_csv('/content/drive/MyDrive/data_deep_learning/titanic_machine_learning_dataset_kaggle.csv')
data.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %% [markdown]
# Data Understanding

# %%
data.keys()
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass  ...       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  ...  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642  ...    0.523008    0.381594   32.204208
# std     257.353842    0.486592    0.836071  ...    1.102743    0.806057   49.693429
# min       1.000000    0.000000    1.000000  ...    0.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000  ...    0.000000    0.000000    7.910400
# 50%     446.000000    0.000000    3.000000  ...    0.000000    0.000000   14.454200
# 75%     668.500000    1.000000    3.000000  ...    1.000000    0.000000   31.000000
# max     891.000000    1.000000    3.000000  ...    8.000000    6.000000  512.329200
#
# [8 rows x 7 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
plt.style.use('ggplot')

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sns.heatmap(data.isnull(),cmap='viridis',cbar=True)

# %%
corr=data.corr()
sns.heatmap(corr,annot=True)

# %%
data1=data.drop(['PassengerId'],axis=1)
cate_feature=[feature for feature in data1.columns if data1[feature].dtype=='O']
num_feature=[feature for feature in data1.columns if data1[feature].dtype!='O']
data1[cate_feature].head()
# Out:
#                                                 Name     Sex  ... Cabin Embarked
# 0                            Braund, Mr. Owen Harris    male  ...   NaN        S
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  ...   C85        C
# 2                             Heikkinen, Miss. Laina  female  ...   NaN        S
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  ...  C123        S
# 4                           Allen, Mr. William Henry    male  ...   NaN        S
#
# [5 rows x 5 columns]

# %%
data1[num_feature].head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare
# 0         0       3  22.0      1      0   7.2500
# 1         1       1  38.0      1      0  71.2833
# 2         1       3  26.0      0      0   7.9250
# 3         1       1  35.0      1      0  53.1000
# 4         0       3  35.0      0      0   8.0500

# %%
fig,ax=plt.subplots(3,3,figsize=(16,16))
sns.countplot(data1['Survived'],ax=ax[0][0])
sns.countplot(data1['Pclass'],ax=ax[0][1])
sns.countplot(data1['SibSp'],ax=ax[0][2])
sns.countplot(data1['Parch'],ax=ax[1][0])
sns.countplot(data1['Sex'],ax=ax[1][1])
sns.countplot(data1['Embarked'],ax=ax[1][2])
sns.distplot(data1['Age'],ax=ax[2][0])
sns.distplot(data1['Fare'],ax=ax[2][1])
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ...

# %% [markdown]
# Survived

# %%
data1['Survived'].plot.hist()

# %%
data1['Survived'].value_counts().plot.pie(autopct='%1.2f%%')

# %% [markdown]
# Pclass

# %%
data1['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
data1.groupby(['Pclass','Survived'])['Survived'].count().plot.bar()

# %%
sns.countplot(data1['Pclass'],hue=data1['Survived'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
data1['Pclass'].value_counts().plot.pie(autopct='%1.2f%%')

# %%
sns.catplot(x='Pclass',y='Survived',kind='bar',data=data1)

# %%
sns.catplot(x='Pclass',y='Survived',kind='point',data=data1)

# %% [markdown]
# Sex

# %%
data1['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
sns.countplot(data1['Sex'],hue=data1['Survived'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.catplot(x='Sex',y='Survived',kind='bar',data=data1,hue='Pclass')

# %%
sns.catplot(x='Sex',y='Survived',kind='bar',data=data1,col='Pclass')

# %%
sns.catplot(x='Sex',y='Survived',data=data1,kind='point')

# %%
sns.catplot(x='Sex',y='Survived',data=data1,kind='point',hue='Pclass')

# %%
sns.catplot(x='Pclass',y='Survived',data=data1,kind='point',hue='Sex')

# %% [markdown]
# Age

# %%
data1['Age'].plot.hist()

# %%
sns.distplot(data1['Age'],bins=30)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(x=data1['Sex'],y=data1['Age'])

# %%
sns.catplot(x='Sex',y='Age',data=data1,col='Pclass',kind='box')

# %%
sns.catplot(x='Sex',y='Age',data=data1,col='Pclass',kind='violin')

# %% [markdown]
# Fare
